# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import PyDAQ 
import control
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
setpoint = 0.15
lazo1 = control.PIDController(setpoint, kp=1.0, ki=0.0, kd=0.0,tau_i=50)

# %%
######## solo proporcional ############
for i in range(1000):
    data = PyDAQ.adquirir1canal()
    medicion = np.mean(data)
    senal = lazo1.calculate(medicion)
    PyDAQ.write(senal)

lazo1.plots()
# Out:
# 0
# 0.13965412522913745
# 0.13958368638446272

# %%
print(senal)
# Out:
# -0.3549271913083525
